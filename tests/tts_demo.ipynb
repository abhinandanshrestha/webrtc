# %%
# !pip install git+https://github.com/huggingface/transformers.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-jboz7zxu
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting regex!=2019.12.17
#   Downloading regex-2024.7.24-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (778 kB)
#      |████████████████████████████████| 778 kB 602 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17 in /home/oem/webrtc/myvenv/lib/python3.8/site-packages (from transformers==4.45.0.dev0) (1.24.4)
# Requirement already satisfied: filelock in /home/oem/webrtc/myvenv/lib/python3.8/site-packages (from transformers==4.45.0.dev0) (3.15.4)
# Collecting tqdm>=4.27
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 20.7 MB/s eta 0:00:01
# Collecting huggingface-hub<1.0,>=0.23.2
#   Downloading huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
#      |████████████████████████████████| 417 kB 12.4 MB/s eta 0:00:01
# Collecting tokenizers<0.20,>=0.19
#   Downloading tokenizers-0.19.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: pyyaml>=5.1 in /home/oem/webrtc/myvenv/lib/python3.8/site-packages (from transformers==4.45.0.dev0) (6.0.1)
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.4.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (436 kB)
#      |████████████████████████████████| 436 kB 6.1 MB/s eta 0:00:01
# Requirement already satisfied: requests in /home/oem/webrtc/myvenv/lib/python3.8/site-packages (from transformers==4.45.0.dev0) (2.32.3)
# Requirement already satisfied: packaging>=20.0 in /home/oem/webrtc/myvenv/lib/python3.8/site-packages (from transformers==4.45.0.dev0) (24.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/oem/webrtc/myvenv/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.0.dev0) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/oem/webrtc/myvenv/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.0.dev0) (2024.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/oem/webrtc/myvenv/lib/python3.8/site-packages (from requests->transformers==4.45.0.dev0) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/oem/webrtc/myvenv/lib/python3.8/site-packages (from requests->transformers==4.45.0.dev0) (2.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/oem/webrtc/myvenv/lib/python3.8/site-packages (from requests->transformers==4.45.0.dev0) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/oem/webrtc/myvenv/lib/python3.8/site-packages (from requests->transformers==4.45.0.dev0) (3.3.2)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (PEP 517) ... done
#   Created wheel for transformers: filename=transformers-4.45.0.dev0-py3-none-any.whl size=9639022 sha256=be028087f9c8b6a5961497699598d983d31004823bf6f7cc992e0ef7dd6edeb5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tn5il30y/wheels/05/0a/97/64ae47c27ba95fae2cb5838e7b4b7247a34d4a8ba5f7092de2
# Successfully built transformers
# Installing collected packages: regex, tqdm, huggingface-hub, tokenizers, safetensors, transformers
# Successfully installed huggingface-hub-0.24.6 regex-2024.7.24 safetensors-0.4.4 tokenizers-0.19.1 tqdm-4.66.5 transformers-4.45.0.dev0
# WARNING: You are using pip version 20.2.1; however, version 24.2 is available.
# You should consider upgrading via the '/home/oem/webrtc/myvenv/bin/python3.8 -m pip install --upgrade pip' command.

# %%
from transformers import AutoProcessor, BarkModel
from IPython.display import Audio
processor = AutoProcessor.from_pretrained("suno/bark")
model = BarkModel.from_pretrained("suno/bark")

voice_preset = "v2/en_speaker_6"

inputs = processor("Hello, my dog is cute", voice_preset=voice_preset)

audio_array = model.generate(**inputs)
audio_array = audio_array.cpu().numpy().squeeze()

# sample_rate = model.generation_config.sample_rate
# Audio(audio_array, rate=sample_rate)
# Out:
# /home/oem/webrtc/myvenv/lib/python3.8/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# /home/oem/webrtc/myvenv/lib/python3.8/site-packages/transformers/models/encodec/modeling_encodec.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer("padding_total", torch.tensor(kernel_size - stride, dtype=torch.int64), persistent=False)
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 10
#       6 voice_preset = "v2/en_speaker_6"
#       8 inputs = processor("Hello, my dog is cute", voice_preset=voice_preset)
# ---> 10 audio_array = model.generate(**inputs)
#      11 audio_array = audio_array.cpu().numpy().squeeze()
#      13 # sample_rate = model.generation_config.sample_rate
#      14 # Audio(audio_array, rate=sample_rate)
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/transformers/models/bark/modeling_bark.py:1731, in BarkModel.generate(self, input_ids, history_prompt, return_output_lengths, **kwargs)
#    1723 semantic_output = self.semantic.generate(
#    1724     input_ids,
#    1725     history_prompt=history_prompt,
#    1726     semantic_generation_config=semantic_generation_config,
#    1727     **kwargs_semantic,
#    1728 )
#    1730 # 2. Generate from the coarse model
# -> 1731 coarse_output = self.coarse_acoustics.generate(
#    1732     semantic_output,
#    1733     history_prompt=history_prompt,
#    1734     semantic_generation_config=semantic_generation_config,
#    1735     coarse_generation_config=coarse_generation_config,
#    1736     codebook_size=self.generation_config.codebook_size,
#    1737     return_output_lengths=return_output_lengths,
#    1738     **kwargs_coarse,
#    1739 )
#    1741 output_lengths = None
#    1742 if return_output_lengths:
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/transformers/models/bark/modeling_bark.py:1111, in BarkCoarseModel.generate(self, semantic_output, semantic_generation_config, coarse_generation_config, codebook_size, history_prompt, return_output_lengths, **kwargs)
#    1097 input_coarse = torch.hstack(
#    1098     [
#    1099         input_coarse,
#    (...)
#    1102     ]
#    1103 )
#    1105 alternatingLogitsProcessor = AlternatingCodebooksLogitsProcessor(
#    1106     input_coarse.shape[1],
#    1107     semantic_generation_config.semantic_vocab_size,
#    1108     codebook_size,
#    1109 )
# -> 1111 output_coarse = super().generate(
#    1112     input_coarse,
#    1113     logits_processor=[alternatingLogitsProcessor],
#    1114     max_new_tokens=min(sliding_window_len, max_generated_len - total_generated_len),
#    1115     generation_config=coarse_generation_config,
#    1116     **kwargs,
#    1117 )
#    1119 input_coarse_len = input_coarse.shape[1]
#    1121 x_coarse = torch.hstack([x_coarse, output_coarse[:, input_coarse_len:]])
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/transformers/generation/utils.py:2015, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2007     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2008         input_ids=input_ids,
#    2009         expand_size=generation_config.num_return_sequences,
#    2010         is_encoder_decoder=self.config.is_encoder_decoder,
#    2011         **model_kwargs,
#    2012     )
#    2014     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2015     result = self._sample(
#    2016         input_ids,
#    2017         logits_processor=prepared_logits_processor,
#    2018         stopping_criteria=prepared_stopping_criteria,
#    2019         generation_config=generation_config,
#    2020         synced_gpus=synced_gpus,
#    2021         streamer=streamer,
#    2022         **model_kwargs,
#    2023     )
#    2025 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2026     # 11. prepare beam search scorer
#    2027     beam_scorer = BeamSearchScorer(
#    2028         batch_size=batch_size,
#    2029         num_beams=generation_config.num_beams,
#    (...)
#    2034         max_length=generation_config.max_length,
#    2035     )
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/transformers/generation/utils.py:2961, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2958 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    2960 # forward pass to get next token
# -> 2961 outputs = self(**model_inputs, return_dict=True)
#    2963 if synced_gpus and this_peer_finished:
#    2964     continue  # don't waste resources running the code we don't need
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/transformers/models/bark/modeling_bark.py:748, in BarkCausalModel.forward(self, input_ids, past_key_values, attention_mask, position_ids, head_mask, labels, input_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     738     outputs = self._gradient_checkpointing_func(
#     739         block.__call__,
#     740         hidden_states,
#    (...)
#     745         output_attentions,
#     746     )
#     747 else:
# --> 748     outputs = block(
#     749         hidden_states,
#     750         past_key_values=past_layer_key_values,
#     751         attention_mask=attention_mask,
#     752         head_mask=head_mask[i],
#     753         use_cache=use_cache,
#     754         output_attentions=output_attentions,
#     755     )
#     757 hidden_states = outputs[0]
#     759 if use_cache:
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/transformers/models/bark/modeling_bark.py:358, in BarkBlock.forward(self, hidden_states, past_key_values, attention_mask, head_mask, use_cache, output_attentions)
#     355 outputs = attn_outputs[1:]
#     357 intermediary_hidden_states = hidden_states + attn_output
# --> 358 intermediary_hidden_states = intermediary_hidden_states + self.mlp(
#     359     self.layernorm_2(intermediary_hidden_states)
#     360 )
#     362 if use_cache:
#     363     outputs = (intermediary_hidden_states,) + outputs
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/transformers/models/bark/modeling_bark.py:311, in BarkMLP.forward(self, hidden_states)
#     309 hidden_states = self.in_proj(hidden_states)
#     310 hidden_states = self.gelu(hidden_states)
# --> 311 hidden_states = self.out_proj(hidden_states)
#     312 hidden_states = self.dropout(hidden_states)
#     313 return hidden_states
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/webrtc/myvenv/lib/python3.8/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import scipy

sample_rate = model.generation_config.sample_rate
scipy.io.wavfile.write("bark_out.wav", rate=sample_rate, data=audio_array)
